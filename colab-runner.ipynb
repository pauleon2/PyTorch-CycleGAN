# %% [markdown]
# # RL project

# %% [markdown]
# ## Mount google drive to save current models ther

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# After the drive is mounted for the first time, go to the files section, go to drive/MyDrive and create an empty folder there called *models*.

# %%
! ls -l
# Out:
# total 52
# -rw-r--r-- 1 root root  136 May 10 14:10 check-cuda.py
# -rw-r--r-- 1 root root 1562 May 10 14:10 config.py
# -rw-r--r-- 1 root root 5044 May 10 14:10 dqn.py
# drwx------ 5 root root 4096 May 10 13:43 drive
# -rw-r--r-- 1 root root 2917 May 10 14:10 evaluate.py
# drwxr-xr-x 2 root root 4096 May 10 14:11 __pycache__
# -rw-r--r-- 1 root root   36 May 10 14:10 requirements.txt
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data
# -rw-r--r-- 1 root root 5207 May 10 14:10 train.py
# -rw-r--r-- 1 root root  454 May 10 14:10 utils.py
# drwxr-xr-x 3 root root 4096 May 10 14:16 wandb

# %%
 # %xmode
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# ## Set up wandb

# %%
# %%capture
# !pip install wandb

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# ## Check if cuda is ther

# %%
! python check-cuda.py
# Out:
# cuda

# %% [markdown]
# ## Start running experiments

# %%
! python train.py --env Pong-v0 --logwandb True
# Out:
# wandb: Currently logged in as: paul-h (use `wandb login --relogin` to force relogin)
# 2021-05-10 16:00:52.241426: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.30
# wandb: Syncing run pretty-sea-4
# wandb: ⭐️ View project at https://wandb.ai/paul-h/reinforcement-learning-pong
# wandb: 🚀 View run at https://wandb.ai/paul-h/reinforcement-learning-pong/runs/3t03j6en
# wandb: Run data is saved locally in /content/wandb/run-20210510_160051-3t03j6en
# wandb: Run `wandb offline` to turn off syncing.
#
# Episode 0/100000: -21.0
# Best performance so far! Saving model.
# Episode 25/100000: -21.0
# Best performance so far! Saving model.
# Episode 50/100000: -21.0
# Best performance so far! Saving model.
# Episode 75/100000: -21.0
# Best performance so far! Saving model.
# Episode 100/100000: -21.0
# Best performance so far! Saving model.
# Episode 125/100000: -20.6
# Best performance so far! Saving model.
# Episode 150/100000: -21.0
# Episode 175/100000: -21.0
# Episode 200/100000: -21.0
# Episode 225/100000: -19.4
# Best performance so far! Saving model.
# Episode 250/100000: -19.8
# Episode 275/100000: -20.6
# Episode 300/100000: -19.8
# Episode 325/100000: -19.0
# Best performance so far! Saving model.
# Episode 350/100000: -17.8
# Best performance so far! Saving model.
# Episode 375/100000: -18.8
# Episode 400/100000: -16.4
# Best performance so far! Saving model.
# Episode 425/100000: -14.8
# Best performance so far! Saving model.
# Episode 450/100000: -13.2
# Best performance so far! Saving model.
# Episode 475/100000: -16.4
# Episode 500/100000: -15.2
# Episode 525/100000: -11.8
# Best performance so far! Saving model.
# Episode 550/100000: -10.6
# Best performance so far! Saving model.
# Episode 575/100000: -9.0
# Best performance so far! Saving model.
# Episode 600/100000: -5.4
# Best performance so far! Saving model.
# Episode 625/100000: 2.0
# Best performance so far! Saving model.
# Episode 650/100000: -4.6
# Episode 675/100000: 3.0
# Best performance so far! Saving model.
# Episode 700/100000: -3.2
# Episode 725/100000: 6.6
# Best performance so far! Saving model.
# Episode 750/100000: -3.6
# Episode 775/100000: 1.0
# Episode 800/100000: 1.6
# Episode 825/100000: 1.2
# Episode 850/100000: 2.6
# Episode 875/100000: 5.8
# Episode 900/100000: 2.4
# Episode 925/100000: 1.6
# Episode 950/100000: -7.8
# Episode 975/100000: 1.6
# Episode 1000/100000: -0.8
# Episode 1025/100000: 4.4
# Episode 1050/100000: 8.0
# Best performance so far! Saving model.
# Episode 1075/100000: -2.0
# Episode 1100/100000: -1.0
# Episode 1125/100000: 13.2
# Best performance so far! Saving model.
# Episode 1150/100000: 1.2
# Episode 1175/100000: 0.8
# Episode 1200/100000: 3.0
# Traceback (most recent call last):
#   File "train.py", line 90, in <module>
#     action = dqn.act(obs_stack)
#   File "/content/dqn.py", line 88, in act
#     max_action = torch.argmax(self.forward(observation), dim=1)
#   File "/content/dqn.py", line 67, in forward
#     x = self.fc2(x)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/linear.py", line 94, in forward
#     return F.linear(input, self.weight, self.bias)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py", line 1753, in linear
#     return torch._C._nn.linear(input, weight, bias)
# KeyboardInterrupt
#
# wandb: Waiting for W&B process to finish, PID 1467
# wandb: Program failed with code 255.  Press ctrl-c to abort syncing.
# wandb:
# wandb: Find user logs for this run at: /content/wandb/run-20210510_160051-3t03j6en/logs/debug.log
# wandb: Find internal logs for this run at: /content/wandb/run-20210510_160051-3t03j6en/logs/debug-internal.log
# wandb: Run summary:
# wandb:   mean return 3.0
# wandb:       episode 1200
# wandb:      _runtime 26877
# wandb:    _timestamp 1620689328
# wandb:         _step 48
# wandb: Run history:
# wandb:   mean return ▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▃▂▂▃▃▄▆▆▅▇▅▆▆▆▆▆▄▆▅▆▅▅█▆▆
# wandb:       episode ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:      _runtime ▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇██
# wandb:    _timestamp ▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇██
# wandb:         _step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced pretty-sea-4: https://wandb.ai/paul-h/reinforcement-learning-pong/runs/3t03j6en
